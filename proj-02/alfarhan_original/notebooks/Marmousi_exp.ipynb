# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
import gc
import os
import time
import datetime
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import scipy as sp
import cv2
from tqdm.notebook import tqdm
from skimage.metrics import structural_similarity as ssim
import deepwave

from deepinvhessian import fwi
from deepinvhessian.utilities import *
from deepinvhessian.filters import *
from deepinvhessian.train import *
from deepinvhessian.masks import *
from unet import *

# %%
set_seed(14)
# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA RTX A4500
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ## Prepare data

# %%
# Define the model and acquisition parameters
par = {'nx':601,   'dx':0.015, 'ox':0,
       'nz':221,   'dz':0.015, 'oz':0,
       'num_shots':30,    'ds':0.3,   'os':0,  'sz':0,
       'num_receivers_per_shot':300,   'dr':0.03,  'orec':0, 'rz':0,
       'nt':5000,  'dt':0.001,  'ot':0,
       'freq': 5, 'num_sources_per_shot':1, 'num_dims':2,
       'num_batches':30,
        'FWI_itr': 100
      }

velocity_file = '../data/Marm.bin'

# %%
# Load the true model
model_true = (np.fromfile(velocity_file, np.float32)
              .reshape(par['nz'], par['nx']))

# function to get water layer mask
def mask(model,value):
    """
    Return a mask for the model (m) using the (value)
    """
    mask = model > value
    mask = mask.astype(int)
    mask[:21] = 0
    return mask

mask = mask(model_true, 1.5)

# %%
m_vmin, m_vmax = np.percentile(model_true, [2,98]) 
show_model(model_true, cmap='jet', vmin=m_vmin, vmax=m_vmax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='Marmousi true model')

# %%
# Create initial guess model for inversion by smoothing the true model
model_init = sp.ndimage.gaussian_filter(model_true, sigma=[10,15])
model_init = model_init * mask
model_init[model_init==0] = 1.5 # km/s
model_init = model_init.astype(np.float32)
show_model(model_init, cmap='jet', vmin=m_vmin, vmax=m_vmax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='Marmousi initial model')

# %%
# Create the source the wavelet
source_wavelet = deepwave.wavelets.ricker(par['freq'], par['nt'], par['dt'], 1/par['freq'])
# Initialize the FWI class
params = fwi.FWIParams(par, torch.tensor(source_wavelet), 1)
# Get the source receiver coordinates
x_s1, x_r1 = params.get_coordinate(1)
# Create a wavelet for every source
source_amplitudes = params.create_wavelet(torch.tensor(source_wavelet))

# %%
# Visualize the source wavelet
plt.plot(np.arange(0,par['nt'])*par['dt'], source_amplitudes[0,0,:])
plt.xlabel('Time (s)')
plt.title('Source wavelet')
# Out:
# Text(0.5, 1.0, 'Source wavelet')

# %%
# Simulate the true data
data_true = fwi.forward_modelling(params, torch.tensor(model_true).float(), device)

# %%
# Visualize the true data
show_3_shots(data_true.cpu(), [0, 14, 29], clip=0.01, extent=(0,int(par['nx']*par['dx']), int(par['nt']*par['dt']), 0), 
        ylim=(int(par['nt']*par['dt']), 0),)

# %% [markdown]
# ## Run FWI with the Barzilai-Borwein method

# %%
# Create folder to save the results
exp_name = f'Exp_Marmousi_BB'
if os.path.isdir(exp_name) is False:
    os.makedirs(exp_name)

# %%
# Run conventional FWI with the Barzilai-Borwein method

# Move data to GPU if using GPU
model = torch.tensor(model_init).clone().to(device)
model.requires_grad = True
data_true = torch.tensor(data_true).float()
mask = torch.tensor(mask).to(device)
# Create lists to save results
gradients, updates, fwi_loss, ssim_list, alphas = [], [], [], [], []

data_range = model_true.max() - model_true.min()
loss_fn = nn.MSELoss() # Misfit function for FWI
optimizer = torch.optim.SGD([{'params': [model], 'lr': 1e-1,}]) # Optimizer to run FWI with step size: lr
tsamples = 0 # Number of time samples starting from zero to exclude from computing the misfit
FWI_iter = 100 # Number of FWI iterations

t_start = time.time()
for iteration in tqdm(range(FWI_iter)):
    # Compute the structural similarity index measure (ssim) between the current and the true models
    ssim_metric = ssim(model.detach().cpu().numpy(), model_true, data_range=data_range)
    ssim_list.append(ssim_metric)
    # Compute FWI gradient
    optimizer.zero_grad()
    grad, iter_loss = fwi.compute_gradient(params, model, data_true, loss_fn, tsamples, device)
    fwi_loss.append(iter_loss)
    print(f'FWI iteration: {iteration} loss = {fwi_loss[-1]}, ssim = {ssim_list[-1]}')
    # Clip the gradient values
    torch.nn.utils.clip_grad_value_(model, torch.quantile(grad.detach().abs(), 0.98))

    if iteration == 0: gmax0 =  torch.abs(grad.detach()).max()
    # Normalize the gradient, mask it around the sources
    grad = (grad /gmax0) * mask
    gradients.append(grad.cpu().detach().numpy())
    # Calculate the step size
    if iteration > 0:
        delta_model = model.detach().clone() - previous_model
        delta_grad = grad.detach().clone() - previous_grad
        alpha = fwi.bb_step(delta_model, delta_grad, 'short')
        alphas.append(alpha)
        optimizer.param_groups[-1]['lr'] = alpha
    # Save the current solution and gradient for calculating the step size in the next iteration
    previous_model = model.detach().clone()
    previous_grad = grad.detach().clone()
    # Update the model
    model.grad.data[:] = grad
    optimizer.step()
    updates.append(model.detach().clone().cpu().numpy())
    # Plot the results
    # show_one_iter_fwi(grad.cpu(), model.detach().cpu(), iteration=iteration,
    #             cmap='bwr', vmin=m_vmin, vmax=m_vmax, extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0), save_path=f'{exp_name}')
t_end = time.time()
t_delta = t_end - t_start
print(f'Runtime:{datetime.timedelta(seconds=t_delta)}')

# Save the results
np.savez(f'{exp_name}/losses', fwi_loss=np.array(fwi_loss), ssim=np.array(ssim_list), alphas=np.array(alphas))
np.savez(f'{exp_name}/results', updates=np.array(updates), gradients=np.array(gradients) )
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# FWI iteration: 0 loss = 1.4478882254203492e-13, ssim = 0.5929408342609036
# FWI iteration: 1 loss = 1.280453076919792e-13, ssim = 0.5937060412791263
# FWI iteration: 2 loss = 8.944859103988493e-14, ssim = 0.5965131072716053
# FWI iteration: 3 loss = 7.886735539995871e-14, ssim = 0.5985165876180583
# FWI iteration: 4 loss = 7.362247001819512e-14, ssim = 0.5996193441788105
# FWI iteration: 5 loss = 7.090695557294447e-14, ssim = 0.6005327726025099
# FWI iteration: 6 loss = 6.714451269652111e-14, ssim = 0.6020271419465474
# FWI iteration: 7 loss = 5.878279509654819e-14, ssim = 0.6062301049976447
# FWI iteration: 8 loss = 5.33203177926567e-14, ssim = 0.6107917610455431
# FWI iteration: 9 loss = 5.1520496107738435e-14, ssim = 0.6114654123658214
# FWI iteration: 10 loss = 5.065347126298759e-14, ssim = 0.6119285453045825
# FWI iteration: 11 loss = 5.00897079302763e-14, ssim = 0.6123943163751018
# FWI iteration: 12 loss = 4.5557653572014254e-14, ssim = 0.6162432633565379
# FWI iteration: 13 loss = 3.7720962285789014e-14, ssim = 0.6239851243406415
# FWI iteration: 91 loss = 5.298469130699193e-15, ssim = 0.6847033909461324
# FWI iteration: 92 loss = 5.2809552845587e-15, ssim = 0.6848081118108257
# FWI iteration: 93 loss = 5.274876030275745e-15, ssim = 0.684828100718967
# FWI iteration: 94 loss = 5.271283834132519e-15, ssim = 0.6848477487404236
# FWI iteration: 95 loss = 5.264304324998791e-15, ssim = 0.6848848695763918
# FWI iteration: 96 loss = 5.137057904054311e-15, ssim = 0.6855746540160851
# FWI iteration: 97 loss = 4.996712499745369e-15, ssim = 0.6863500320959038
# FWI iteration: 98 loss = 4.976969827576335e-15, ssim = 0.6865757614266815
# FWI iteration: 99 loss = 4.952395898293006e-15, ssim = 0.6865945122129752
# Runtime:0:08:09.370735

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,4))
axs[0].plot(fwi_loss)
axs[0].set_title('Data Loss')
axs[0].set_xlabel('Iteration')
axs[0].spines['right'].set_visible(False)
axs[0].spines['top'].set_visible(False)
axs[1].plot(ssim_list)
axs[1].set_title('SSIM')
axs[1].set_xlabel('Iteration')
axs[1].spines['right'].set_visible(False)
axs[1].spines['top'].set_visible(False)
plt.savefig(f'{exp_name}/losses.png',  bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(np.arange(FWI_iter), np.concatenate([[1e-1], alphas]))
ax.set_xlabel('Iteration', fontsize=14)
ax.set_ylabel(r'$\alpha$', fontsize=14)
ax.set_title('Barzilai-Borwein step size', fontsize=16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(f'{exp_name}/alpha.png',  bbox_inches='tight', dpi=300)

# %%
show_model(updates[0], cmap='jet', vmin=m_vmin, vmax=m_vmax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='First update')

# %%
show_model(updates[-1], cmap='jet', vmin=m_vmin, vmax=m_vmax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='Last update')

# %% [markdown]
# ## Run FWI with the proposed approach $\delta m$

# %%
# Compute source illumination
SI = fwi.source_illumination(torch.tensor(model_init), source_amplitudes, par['dx'], par['dt'], x_s1, device=device)
# clear memory
torch.cuda.empty_cache()
gc.collect()
# Visualize the source illumination
simin, simax = np.percentile(SI.cpu(), [2,98])
show_model(SI.cpu(), cmap='bwr', vmin=simin, vmax=simax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='Source Illumination')
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Compute source illumination
# ----> 2 SI = fwi.source_illumination(torch.tensor(model_init), source_amplitudes, par['dx'], par['dt'], x_s1, device=device)
#       3 # clear memory
#       4 torch.cuda.empty_cache()
#       5 gc.collect()
#
# File /mnt/storage_C1/eliani_beloni/geofisica/piml-pub/proj-02/src/deepinvhessian/fwi.py:28, in source_illumination(model, source, dx, dt, x_s, device)
#      13 class FWIParams:
#      14     """
#      15     A class to hold parameters and functions for Full Waveform Inversion (FWI).
#      16
#      17     This class initializes and stores the parameters required for FWI and provides
#      18     methods to calculate source and receiver coordinates, as well as to create wavelets.
#      19
#      20     Attributes
#      21     ----------
#      22     nx : int
#      23         Number of grid points in the x-direction.
#      24     nz : int
#      25         Number of grid points in the z-direction.
#      26     dx : float
#      27         Grid spacing in the x-direction.
# ---> 28     nt : int
#      29         Number of time samples.
#      30     dt : float
#      31         Time sampling interval.
#      32     num_dims : int
#      33         Number of dimensions.
#      34     num_shots : int
#      35         Number of shots.
#      36     num_batches : int
#      37         Number of batches.
#      38     num_sources_per_shot : int
#      39         Number of sources per shot.
#      40     num_receivers_per_shot : int
#      41         Number of receivers per shot.
#      42     ds : int or torch.Tensor
#      43         Spacing between sources.
#      44     dr : int or torch.Tensor
#      45         Spacing between receivers.
#      46     sz : torch.Tensor
#      47         Depth of sources.
#      48     rz : torch.Tensor
#      49         Depth of receivers.
#      50     os : float
#      51         Offset of sources.
#      52     orec : float
#      53         Offset of receivers.
#      54     ox : float
#      55         Offset in the x-direction.
#      56     freq : float
#      57         Dominant frequency of the wavelet.
#      58     wavelet : torch.Tensor
#      59         Source wavelet tensor.
#      60     s_cor : torch.Tensor
#      61         Source locations [num_shots, num_sources_per_shot, num_dimensions].
#      62     r_cor : torch.Tensor
#      63         Receiver locations [num_shots, num_receivers_per_shot, num_dimensions].
#      64
#      65     Methods
#      66     -------
#      67     get_coordinate(acquisition: int | str) -> tuple[torch.Tensor, torch.Tensor]
#      68         Calculate source and receiver coordinates based on the acquisition mode.
#      69     create_wavelet(wavelet: torch.Tensor, scale: float = 1.0) -> torch.Tensor
#      70         Create a tensor of source amplitudes from the wavelet values with an optional scale.
#      71     """
#      73     def __init__(self, par: dict, wavelet: torch.Tensor, acquisition: int | str):
#      74         """
#      75         Initialize an instance to apply FWI.
#      76
#    (...)     87             'volve': Custom mode for handling Volve dataset.
#      88         """
#
# File ~/.conda/envs/deepinvhessian/lib/python3.11/site-packages/deepwave/scalar.py:481, in scalar(v, grid_spacing, dt, source_amplitudes, source_locations, receiver_locations, accuracy, pml_width, pml_freq, max_vel, survey_pad, wavefield_0, wavefield_m1, psiz_m1, psiy_m1, psix_m1, zetaz_m1, zetay_m1, zetax_m1, origin, nt, model_gradient_sampling_interval, freq_taper_frac, time_pad_frac, time_taper, forward_callback, backward_callback, callback_frequency, python_backend, storage_mode, storage_path, storage_compression)
#     458     max_model_vel = v.abs().max().item()
#     459 fd_pad = [accuracy // 2] * 2 * ndim
#     460 (
#     461     models,
#     462     source_amplitudes_out,
#     463     wavefields,
#     464     sources_i,
#     465     receivers_i,
#     466     grid_spacing,
#     467     dt,
#     468     nt,
#     469     n_shots,
#     470     step_ratio,
#     471     model_gradient_sampling_interval,
#     472     accuracy,
#     473     pml_width,
#     474     pml_freq,
#     475     max_vel,
#     476     freq_taper_frac,
#     477     time_pad_frac,
#     478     time_taper,
#     479     device,
#     480     dtype,
# --> 481 ) = deepwave.common.setup_propagator(
#     482     [v],
#     483     ["replicate"],
#     484     grid_spacing,
#     485     dt,
#     486     [source_amplitudes],
#     487     [source_locations],
#     488     [receiver_locations],
#     489     accuracy,
#     490     fd_pad,
#     491     pml_width,
#     492     pml_freq,
#     493     max_vel,
#     494     min_nonzero_model_vel,
#     495     max_model_vel,
#     496     survey_pad,
#     497     initial_wavefields,
#     498     origin,
#     499     nt,
#     500     model_gradient_sampling_interval,
#     501     freq_taper_frac,
#     502     time_pad_frac,
#     503     time_taper,
#     504     ndim,
#     505 )
#     506 del v, source_amplitudes, source_locations, receiver_locations
#     508 # In the finite difference implementation, the source amplitudes we
#     509 # add to the wavefield each time step are multiplied by
#     510 # -v^2 * dt^2 (where v is the velocity model, stored in models[0]).
#    (...)    513 # avoid out-of-bounds accesses to the model. Since these sources will not be
#     514 # used, their amplitudes are not important.
#
# File ~/.conda/envs/deepinvhessian/lib/python3.11/site-packages/deepwave/common.py:591, in setup_propagator(models, model_pad_modes, grid_spacing, dt, source_amplitudes, source_locations, receiver_locations, accuracy, fd_pad, pml_width, pml_freq, max_vel, min_nonzero_model_vel, max_model_vel, survey_pad, wavefields, origin, nt, model_gradient_sampling_interval, freq_taper_frac, time_pad_frac, time_taper, ndims)
#     578 check_source_amplitudes_locations_match(source_amplitudes, source_locations)
#     579 source_amplitudes_out = set_source_amplitudes(
#     580     source_amplitudes,
#     581     n_batch,
#    (...)    588     dtype,
#     589 )
#     590 models_out, source_locations_out, receiver_locations_out, wavefields_out = (
# --> 591     extract_survey(
#     592         models,
#     593         source_locations,
#     594         receiver_locations,
#     595         wavefields,
#     596         survey_pad,
#     597         origin,
#     598         fd_pad,
#     599         pml_width,
#     600         model_pad_modes,
#     601         n_batch,
#     602         ndims,
#     603         device,
#     604         dtype,
#     605     )
#     606 )
#     607 return (
#     608     models_out,
#     609     source_amplitudes_out,
#    (...)    627     dtype,
#     628 )
#
# File ~/.conda/envs/deepinvhessian/lib/python3.11/site-packages/deepwave/common.py:1572, in extract_survey(models, source_locations, receiver_locations, wavefields, survey_pad, origin, fd_pad, pml_width, model_pad_modes, n_batch, ndims, device, dtype)
#    1543     survey_extents = get_survey_extents_from_locations(
#    1544         model_spatial_shape,
#    1545         locations,
#    1546         survey_pad,
#    1547     )
#    1548     check_extents_match_wavefields_shape(survey_extents, wavefields, pml_width)
#    1549 return (
#    1550     list(
#    1551         extract_models(
#    1552             models,
#    1553             survey_extents,
#    1554             pad,
#    1555             model_pad_modes,
#    1556             n_batch,
#    1557             device,
#    1558             dtype,
#    1559         ),
#    1560     ),
#    1561     list(
#    1562         extract_locations(
#    1563             "Source",
#    1564             source_locations,
#    1565             survey_extents,
#    1566             pad,
#    1567             n_batch,
#    1568             device,
#    1569         ),
#    1570     ),
#    1571     list(
# -> 1572         extract_locations(
#    1573             "Receiver",
#    1574             receiver_locations,
#    1575             survey_extents,
#    1576             pad,
#    1577             n_batch,
#    1578             device,
#    1579         ),
#    1580     ),
#    1581     list(
#    1582         prepare_wavefields(
#    1583             wavefields,
#    1584             survey_extents,
#    1585             pml_width,
#    1586             n_batch,
#    1587             device,
#    1588             dtype,
#    1589         ),
#    1590     ),
#    1591 )
#
# File ~/.conda/envs/deepinvhessian/lib/python3.11/site-packages/deepwave/common.py:2237, in extract_locations(name, locations, extents, pad, n_batch, device, dtype, eps)
#    2235 if location is not None:
#    2236     _validate_location_tensor(location, name, ndims, n_batch, eps)
# -> 2237     location_1d = _convert_to_1d_and_check_uniqueness(
#    2238         location, name, ndims, n_batch, origin, stride, device
#    2239     )
#    2240     extracted_locations.append(location_1d)
#    2241 else:
#
# File ~/.conda/envs/deepinvhessian/lib/python3.11/site-packages/deepwave/common.py:2178, in _convert_to_1d_and_check_uniqueness(location, name, ndims, n_batch, origin, stride, device)
#    2176     shot_locations = shot_locations[shot_locations != IGNORE_LOCATION]
#    2177     if len(shot_locations) != len(torch.unique(shot_locations)):
# -> 2178         raise RuntimeError(
#    2179             f"{name} locations must be unique within each shot. "
#    2180             "You cannot have two in the same cell, but in shot "
#    2181             f"{batch_idx} there is/are {len(shot_locations)} "
#    2182             f"active {name.lower()} locations while only "
#    2183             f"{len(torch.unique(shot_locations))} is/are unique.",
#    2184         )
#    2185 return location_1d.contiguous()
#
# RuntimeError: Receiver locations must be unique within each shot. You cannot have two in the same cell, but in shot 0 there is/are 132821 active receiver locations while only 127224 is/are unique.

# %%
# Create folder to save the results
exp_name = f'Exp_Marmousi_dm'
if os.path.isdir(exp_name) is False:
    os.makedirs(exp_name)

# %%
# Run FWI with the proposed method

# Move data to GPU if using GPU
model = torch.tensor(model_init).clone().to(device)
model.requires_grad = True
data_true = torch.tensor(data_true).float()
mask = torch.tensor(mask).to(device)
# Create lists to save results
gradients, dm1s, gradients_pred, dms, updates, fwi_loss, ssim_list, network_loss = [], [], [], [], [], [], [], []

data_range = model_true.max() - model_true.min()
loss_fn = torch.nn.MSELoss() # Misfit function for FWI and Born modelling
optimizer = torch.optim.SGD([{'params': [model], 'lr': 1e-2}]) # Optimizer to run FWI with step size: lr
# Create the network, its optimizer and the loss function to train it
network = UNet(n_channels=1, n_classes=1, hidden_channels=128).to(device)
optimizer_unet = torch.optim.Adam(network.parameters(), lr=1e-4)
l2_norm = torch.nn.MSELoss()
network_iter_init = 1000 # Number of epochs to train the network in the first FWI iteration
network_iter_fin = 300 # Number of epochs to train the network in every FWI iteration except the first one
tsamples = 0 # Number of time samples starting from zero to exclude from computing the misfit
FWI_iter = 100 # Number of FWI iterations
t_start = time.time()
for iteration in tqdm(range(FWI_iter)):
    # Compute the structural similarity index measure (ssim) between the current and the true models
    ssim_metric = ssim(model.detach().cpu().numpy(), model_true, data_range=data_range)
    ssim_list.append(ssim_metric)
    # Compute FWI gradient
    optimizer.zero_grad()
    grad, iter_loss = fwi.compute_gradient(params, model, data_true, loss_fn, tsamples, device)
    fwi_loss.append(iter_loss)
    print(f'FWI iteration: {iteration} loss = {fwi_loss[-1]}, ssim = {ssim_list[-1]}')
    # Clip the gradient values
    torch.nn.utils.clip_grad_value_(model, torch.quantile(grad.detach().abs(), 0.98))
    # Apply source illumination to the gradient
    grad = (grad * model.detach().clone()**3 ) / SI
    if iteration == 0: gmax0 =  torch.abs(grad.detach()).max()
    # Normalize the gradient, mask it around the sources and apply taperinn to the shallower and deeper parts
    grad = (grad /gmax0) * mask
    gradients.append(grad.cpu().detach().numpy())
    # Compute dm1 with the gradient as the perturbation
    dm1 = grad.detach().clone().to(device)
    dm1.requires_grad = True
    dm1 = fwi.compute_dm1(params, model.detach().clone(), dm1 , loss_fn, tsamples, device)
    # Apply source illumination to dm1
    dm1 = dm1 * (model.detach().clone() ** 3) / SI
    if iteration == 0: dm1max0 =  1e1 * torch.abs(dm1.detach()).max()
    # Normalize dm1 and mask it around the sources
    dm1 = (dm1 / dm1max0)  * mask
    dm1s.append(dm1.cpu().detach().numpy())
    # Train the network
    training_pair = {'x': dm1.clone().unsqueeze(0).unsqueeze(0),
                    'y': grad.clone().unsqueeze(0).unsqueeze(0)}
    network_iter = network_iter_init if iteration == 0 else network_iter_fin
    lossn = train(network, training_pair, optimizer_unet, l2_norm, network_iter, use_scheduler=True, device=device)
    network_loss.extend(lossn)
    # Get the gradient from the network
    with torch.no_grad():
        g = network(training_pair['x']).squeeze() * mask
    gradients_pred.append(g.cpu().detach().numpy())
    # Get dm from the network
    with torch.no_grad():
        dm = network(training_pair['y']).squeeze() * mask
    dms.append(dm.cpu().detach().numpy())
    # Update the model
    model.grad.data[:] = dm.detach().clone()
    optimizer.step()
    updates.append(model.detach().clone().cpu().numpy())
    # Plot the results
    # show_one_iter_dm(grad.cpu(), dm1.cpu(), g.cpu(), dm.cpu(), model.detach().cpu(), lossn, iteration=iteration,
    #             cmap='bwr', vmin=m_vmin, vmax=m_vmax, extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0), save_path=f'{exp_name}')
t_end = time.time()
t_delta = t_end - t_start
print(f'Runtime:{datetime.timedelta(seconds=t_delta)}')
# Save the results
np.savez(f'{exp_name}/losses', fwi_loss=np.array(fwi_loss),
                               network_loss=np.array(network_loss),
                               ssim=np.array(ssim_list),
                               )
np.savez(f'{exp_name}/results', updates=np.array(updates), 
                            gradients=np.array(gradients), 
                            dm1s=np.array(dm1s),
                            gradients_pred=np.array(gradients_pred),
                            dms=np.array(dms),)
# Save the network weights
torch.save(network.state_dict(), f'{exp_name}/network_weights.pth')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# FWI iteration: 0 loss = 1.4465602697531893e-13, ssim = 0.5929408504557789
# Training Progress:   0%|          | 0/1000 [00:00<?, ?it/s]
# Training Epoch 0, Loss = 0.027595723047852516
# Training Epoch 1, Loss = 0.026424819603562355
# Training Epoch 2, Loss = 0.025294406339526176
# Training Epoch 3, Loss = 0.02407211624085903
# Training Epoch 4, Loss = 0.02276913821697235
# Training Epoch 5, Loss = 0.021332086995244026
# Training Epoch 6, Loss = 0.019791582599282265
# Training Epoch 7, Loss = 0.01823810115456581
# Training Epoch 8, Loss = 0.01686173491179943
# Training Epoch 9, Loss = 0.01615925505757332
# Training Epoch 10, Loss = 0.01656774803996086
# Training Epoch 11, Loss = 0.016400791704654694
# Training Epoch 12, Loss = 0.015524359419941902
# Training Epoch 13, Loss = 0.014435160905122757
# Training Epoch 14, Loss = 0.013418846763670444
# Training Epoch 15, Loss = 0.012557487934827805
# Training Epoch 16, Loss = 0.011842717416584492
# Training Epoch 17, Loss = 0.011239401064813137
# Training Epoch 18, Loss = 0.010725922882556915
# Training Epoch 19, Loss = 0.01031035277992487
# Training Epoch 20, Loss = 0.010005836375057697
# Training Epoch 21, Loss = 0.009740481153130531
# Training Epoch 22, Loss = 0.009498022496700287
# Training Epoch 23, Loss = 0.009340288117527962
# Training Epoch 24, Loss = 0.009184603579342365
# Training Epoch 25, Loss = 0.009036862291395664
# Training Epoch 26, Loss = 0.008927900344133377
# Training Epoch 27, Loss = 0.008822078816592693
# Training Epoch 28, Loss = 0.008664720691740513
# Training Epoch 29, Loss = 0.008597456850111485
# Training Epoch 30, Loss = 0.009592532180249691
# Training Epoch 31, Loss = 0.009474239312112331
# Training Epoch 32, Loss = 0.00852678157389164
# Training Epoch 33, Loss = 0.008786431513726711
# Training Epoch 34, Loss = 0.008942116051912308
# Training Epoch 35, Loss = 0.008581714704632759
# Training Epoch 36, Loss = 0.00850001908838749
# Training Epoch 37, Loss = 0.008688624016940594
# Training Epoch 38, Loss = 0.008424239233136177
# Training Epoch 39, Loss = 0.008209358900785446
# Training Epoch 40, Loss = 0.008360371924936771
# Training Epoch 41, Loss = 0.008156213909387589
# Training Epoch 42, Loss = 0.007935852743685246
# Training Epoch 43, Loss = 0.008068937808275223
# Training Epoch 44, Loss = 0.007856182754039764
# Training Epoch 45, Loss = 0.007968158461153507
# Training Epoch 46, Loss = 0.007718361914157867
# Training Epoch 47, Loss = 0.007751757744699717
# Training Epoch 48, Loss = 0.0077711488120257854
# Training Epoch 49, Loss = 0.007664925418794155
# Training Epoch 50, Loss = 0.00756743922829628
# Training Epoch 51, Loss = 0.007452435325831175
# Training Epoch 52, Loss = 0.007317450363188982
# Training Epoch 53, Loss = 0.009315785951912403
# Training Epoch 54, Loss = 0.010155425406992435
# Training Epoch 55, Loss = 0.008667053654789925
# Training Epoch 56, Loss = 0.008225356228649616
# Training Epoch 57, Loss = 0.00877915695309639
# Training Epoch 58, Loss = 0.009196601808071136
# Training Epoch 59, Loss = 0.00921592116355896
# Training Epoch 60, Loss = 0.00898999534547329
# Training Epoch 61, Loss = 0.008720582351088524
# Training Epoch 62, Loss = 0.00854769628494978
# Training Epoch 63, Loss = 0.008512455970048904
# Training Epoch 64, Loss = 0.008520779199898243
# Training Epoch 65, Loss = 0.008364187553524971
# Training Epoch 66, Loss = 0.007992088794708252
# Training Epoch 67, Loss = 0.008579432033002377
# Training Epoch 68, Loss = 0.008088207803666592
# Training Epoch 69, Loss = 0.008531942032277584
# Training Epoch 70, Loss = 0.008089140057563782
# Training Epoch 71, Loss = 0.0077573820017278194
# Training Epoch 72, Loss = 0.007977154105901718
# Training Epoch 73, Loss = 0.007682598661631346
# Training Epoch 74, Loss = 0.007881499826908112
# Training Epoch 75, Loss = 0.0077308849431574345
# Training Epoch 76, Loss = 0.0075063868425786495
# Training Epoch 77, Loss = 0.007624050602316856
# Training Epoch 78, Loss = 0.007617874536663294
# Training Epoch 79, Loss = 0.007389961741864681
# Training Epoch 80, Loss = 0.007523165550082922
# Training Epoch 81, Loss = 0.007528505753725767
# Training Epoch 82, Loss = 0.007357051596045494
# Training Epoch 83, Loss = 0.007469688542187214
# Training Epoch 84, Loss = 0.007380145136266947
# Training Epoch 85, Loss = 0.007289551664143801
# Training Epoch 86, Loss = 0.0073455017991364
# Training Epoch 87, Loss = 0.007265158463269472
# Training Epoch 88, Loss = 0.007193545810878277
# Training Epoch 89, Loss = 0.007214090786874294
# Training Epoch 90, Loss = 0.007126815151423216
# Training Epoch 91, Loss = 0.007035120856016874
# Training Epoch 156, Loss = 0.002805462572723627
# Training Epoch 157, Loss = 0.002835544990375638
# Training Epoch 158, Loss = 0.0030308435671031475
# Training Epoch 159, Loss = 0.002819184912368655
# Training Epoch 160, Loss = 0.0028236215002834797
# Training Epoch 161, Loss = 0.0025988505221903324
# Training Epoch 162, Loss = 0.0025917217135429382
# Training Epoch 163, Loss = 0.0026516171637922525
# Training Epoch 164, Loss = 0.0027030499186366796
# Training Epoch 165, Loss = 0.002345314249396324
# Training Epoch 166, Loss = 0.00247977371327579
# Training Epoch 167, Loss = 0.002357398858293891
# Training Epoch 168, Loss = 0.0022108107805252075
# Training Epoch 169, Loss = 0.002240690402686596
# Training Epoch 170, Loss = 0.002052380470559001
# Training Epoch 171, Loss = 0.002075934549793601
# Training Epoch 172, Loss = 0.002000126987695694
# Training Epoch 173, Loss = 0.0019251115154474974
# Training Epoch 174, Loss = 0.0019061649218201637
# Training Epoch 175, Loss = 0.0018581891199573874
# Training Epoch 176, Loss = 0.0018053362146019936
# Training Epoch 177, Loss = 0.0019255393417552114
# Training Epoch 178, Loss = 0.0025673559866845608
# Training Epoch 179, Loss = 0.0026923981495201588
# Training Epoch 180, Loss = 0.002316189929842949
# Training Epoch 181, Loss = 0.00224366900511086
# Training Epoch 182, Loss = 0.0022606549318879843
# Training Epoch 183, Loss = 0.002015033271163702
# Training Epoch 184, Loss = 0.0022799563594162464
# Training Epoch 185, Loss = 0.0018848436884582043
# Training Epoch 186, Loss = 0.0020791790448129177
# Training Epoch 187, Loss = 0.0018917261622846127
# Training Epoch 188, Loss = 0.0018410723423585296
# Training Epoch 189, Loss = 0.0019356348784640431
# Training Epoch 190, Loss = 0.0016875126166269183
# Training Epoch 191, Loss = 0.0017693674890324473
# Training Epoch 192, Loss = 0.0016653630882501602
# Training Epoch 193, Loss = 0.0016631162725389004
# Training Epoch 194, Loss = 0.0016241300618276
# Training Epoch 195, Loss = 0.0015780070098116994
# Training Epoch 196, Loss = 0.0015454059466719627
# Training Epoch 197, Loss = 0.0015226434916257858
# Training Epoch 198, Loss = 0.00143821828532964
# Training Epoch 199, Loss = 0.0014569716295227408
# Training Epoch 200, Loss = 0.0014131150674074888
# Training Epoch 201, Loss = 0.0013642330886796117
# Training Epoch 202, Loss = 0.0013716869289055467
# Training Epoch 203, Loss = 0.0013113139430060983
# Training Epoch 204, Loss = 0.0013273810036480427
# Training Epoch 205, Loss = 0.0012610116973519325
# Training Epoch 206, Loss = 0.0012777094962075353
# Training Epoch 207, Loss = 0.0012188778491690755
# Training Epoch 208, Loss = 0.0012333065969869494
# Training Epoch 209, Loss = 0.0011870443122461438
# Training Epoch 210, Loss = 0.0011852906318381429
# Training Epoch 211, Loss = 0.0011575875105336308
# Training Epoch 212, Loss = 0.001132691279053688
# Training Epoch 213, Loss = 0.0011294531868770719
# Training Epoch 214, Loss = 0.0011000982485711575
# Training Epoch 215, Loss = 0.0010970981093123555
# Training Epoch 216, Loss = 0.0010662891436368227
# Training Epoch 217, Loss = 0.0010684099979698658
# Training Epoch 218, Loss = 0.0010455662850290537
# Training Epoch 343, Loss = 0.0003961970505770296
# Training Epoch 344, Loss = 0.00037249427987262607
# Training Epoch 345, Loss = 0.0003810008929576725
# Training Epoch 346, Loss = 0.0003995916631538421
# Training Epoch 347, Loss = 0.0003854763926938176
# Training Epoch 348, Loss = 0.000363668252248317
# Training Epoch 349, Loss = 0.00036610005190595984
# Training Epoch 350, Loss = 0.00037508804234676063
# Training Epoch 351, Loss = 0.0003714426711667329
# Training Epoch 352, Loss = 0.00035870957071892917
# Training Epoch 353, Loss = 0.00035502389073371887
# Training Epoch 354, Loss = 0.00036035056109540164
# Training Epoch 355, Loss = 0.000360142788849771
# Training Epoch 356, Loss = 0.0003528804227244109
# Training Epoch 357, Loss = 0.00034732918720692396
# Training Epoch 358, Loss = 0.00034825404873117805
# Training Epoch 359, Loss = 0.00035041922819800675
# Training Epoch 360, Loss = 0.00034770890488289297
# Training Epoch 361, Loss = 0.0003425712639000267
# Training Epoch 362, Loss = 0.00034066688385792077
# Training Epoch 363, Loss = 0.0003407654585316777
# Training Epoch 364, Loss = 0.0003398715634830296
# Training Epoch 365, Loss = 0.00033786497078835964
# Training Epoch 366, Loss = 0.0003361490380484611
# Training Epoch 367, Loss = 0.000334625510731712
# Training Epoch 368, Loss = 0.0003324644349049777
# Training Epoch 369, Loss = 0.0003307926235720515
# Training Epoch 370, Loss = 0.00033022311981767416
# Training Epoch 371, Loss = 0.00033026927849277854
# Training Epoch 372, Loss = 0.0003295175265520811
# Training Epoch 373, Loss = 0.00032790083787404
# Training Epoch 374, Loss = 0.0003263257094658911
# Training Epoch 375, Loss = 0.0003260353987570852
# Training Epoch 376, Loss = 0.0003292672918178141
# Training Epoch 377, Loss = 0.0003394674859009683
# Training Epoch 378, Loss = 0.0003686505078803748
# Training Epoch 379, Loss = 0.0004236541863065213
# Training Epoch 380, Loss = 0.0005545371095649898
# Training Epoch 381, Loss = 0.0005624603945761919
# Training Epoch 382, Loss = 0.00047838574391789734
# Training Epoch 383, Loss = 0.00034192774910479784
# Training Epoch 384, Loss = 0.0004604259447660297
# Training Epoch 385, Loss = 0.0004981004749424756
# Training Epoch 386, Loss = 0.00033850441104732454
# Training Epoch 387, Loss = 0.0004642011772375554
# Training Epoch 388, Loss = 0.00046284677227959037
# Training Epoch 389, Loss = 0.00035673152888193727
# Training Epoch 390, Loss = 0.0004803772026207298
# Training Epoch 391, Loss = 0.0003892680106218904
# Training Epoch 392, Loss = 0.0004083224630448967
# Training Epoch 393, Loss = 0.00040551996789872646
# Training Epoch 394, Loss = 0.0003710014862008393
# Training Epoch 395, Loss = 0.0003878308634739369
# Training Epoch 396, Loss = 0.00035561289405450225
# Training Epoch 397, Loss = 0.00038531882455572486
# Training Epoch 398, Loss = 0.0003344041178934276
# Training Epoch 399, Loss = 0.000366613210644573
# Training Epoch 400, Loss = 0.0003319630050100386
# Training Epoch 401, Loss = 0.00034815745311789215
# Training Epoch 402, Loss = 0.00033657444873824716
# Training Epoch 403, Loss = 0.000331568211549893
# Training Epoch 404, Loss = 0.0003375736705493182
# Training Epoch 405, Loss = 0.00032195585663430393
# Training Epoch 468, Loss = 0.00027474953094497323
# Training Epoch 469, Loss = 0.000275892874924466
# Training Epoch 470, Loss = 0.0002781865478027612
# Training Epoch 471, Loss = 0.0002824739785864949
# Training Epoch 472, Loss = 0.0002873061166610569
# Training Epoch 473, Loss = 0.00029072689358145
# Training Epoch 474, Loss = 0.0002857893123291433
# Training Epoch 475, Loss = 0.0002764203236438334
# Training Epoch 476, Loss = 0.00027227867394685745
# Training Epoch 477, Loss = 0.0002761101059149951
# Training Epoch 478, Loss = 0.00027663185028359294
# Training Epoch 479, Loss = 0.00027120232698507607
# Training Epoch 480, Loss = 0.00027018444961868227
# Training Epoch 481, Loss = 0.0002736975729931146
# Training Epoch 482, Loss = 0.0002726502134464681
# Training Epoch 483, Loss = 0.00026922530378215015
# Training Epoch 484, Loss = 0.00027011753991246223
# Training Epoch 485, Loss = 0.0002703470236156136
# Training Epoch 486, Loss = 0.00026775096193887293
# Training Epoch 487, Loss = 0.00026752520352602005
# Training Epoch 488, Loss = 0.0002686691586859524
# Training Epoch 489, Loss = 0.000267552153673023
# Training Epoch 490, Loss = 0.00026656288537196815
# Training Epoch 491, Loss = 0.00026694111875258386
# Training Epoch 492, Loss = 0.00026630403590388596
# Training Epoch 493, Loss = 0.0002651293470989913
# Training Epoch 494, Loss = 0.0002650057431310415
# Training Epoch 495, Loss = 0.0002649594680406153
# Training Epoch 496, Loss = 0.0002643172338139266
# Training Epoch 497, Loss = 0.0002639656304381788
# Training Epoch 498, Loss = 0.0002639091107994318
# Training Epoch 499, Loss = 0.0002635158016346395
# Training Epoch 500, Loss = 0.0002629521186463535
# Training Epoch 501, Loss = 0.00026261070161126554
# Training Epoch 502, Loss = 0.0002623402397148311
# Training Epoch 503, Loss = 0.00026191581855528057
# Training Epoch 504, Loss = 0.00026150982012040913
# Training Epoch 505, Loss = 0.0002612873213365674
# Training Epoch 506, Loss = 0.00026106389123015106
# Training Epoch 507, Loss = 0.0002607039059512317
# Training Epoch 508, Loss = 0.0002603813773021102
# Training Epoch 509, Loss = 0.0002601821324788034
# Training Epoch 510, Loss = 0.0002599026483949274
# Training Epoch 511, Loss = 0.0002595294499769807
# Training Epoch 512, Loss = 0.0002592365781310946
# Training Epoch 513, Loss = 0.0002589897776488215
# Training Epoch 514, Loss = 0.0002586654736660421
# Training Epoch 515, Loss = 0.0002583372697699815
# Training Epoch 516, Loss = 0.00025807679048739374
# Training Epoch 517, Loss = 0.00025781296426430345
# Training Epoch 518, Loss = 0.0002575184335000813
# Training Epoch 519, Loss = 0.00025725169689394534
# Training Epoch 520, Loss = 0.00025700157857500017
# Training Epoch 521, Loss = 0.00025672378251329064
# Training Epoch 522, Loss = 0.00025645963614806533
# Training Epoch 523, Loss = 0.0002562275913078338
# Training Epoch 524, Loss = 0.00025597569765523076
# Training Epoch 525, Loss = 0.00025570279103703797
# Training Epoch 526, Loss = 0.0002554631500970572
# Training Epoch 527, Loss = 0.0002552509540691972
# Training Epoch 528, Loss = 0.00025501736672595143
# Training Epoch 529, Loss = 0.00025476524024270475
# Training Epoch 530, Loss = 0.0002545482711866498
# Training Epoch 531, Loss = 0.0002543603186495602
# Training Epoch 532, Loss = 0.0002541651192586869
# Training Epoch 533, Loss = 0.0002539513516239822
# Training Epoch 534, Loss = 0.00025374305550940335
# Training Epoch 535, Loss = 0.0002535454696044326
# Training Epoch 536, Loss = 0.00025334619567729533
# Training Epoch 537, Loss = 0.0002531177597120404
# Training Epoch 538, Loss = 0.0002528650511521846
# Training Epoch 539, Loss = 0.000252599420491606
# Training Epoch 540, Loss = 0.00025234269560314715
# Training Epoch 541, Loss = 0.00025208195438608527
# Training Epoch 542, Loss = 0.0002518132678233087
# Training Epoch 543, Loss = 0.0002515410596970469
# Training Epoch 544, Loss = 0.0002512847713660449
# Training Epoch 545, Loss = 0.0002510477206669748
# Training Epoch 546, Loss = 0.00025082234060391784
# Training Epoch 547, Loss = 0.00025060385814867914
# Training Epoch 548, Loss = 0.00025039512547664344
# Training Epoch 549, Loss = 0.0002501965791452676
# Training Epoch 550, Loss = 0.0002500058326404542
# Training Epoch 551, Loss = 0.00024982212926261127
# Training Epoch 552, Loss = 0.000249645730946213
# Training Epoch 553, Loss = 0.00024947189376689494
# Training Epoch 554, Loss = 0.00024930061772465706
# Training Epoch 555, Loss = 0.0002491286722943187
# Training Epoch 556, Loss = 0.0002489520702511072
# Training Epoch 557, Loss = 0.00024877229589037597
# Training Epoch 558, Loss = 0.00024857596145011485
# Training Epoch 559, Loss = 0.0002483649586793035
# Training Epoch 560, Loss = 0.0002481223491486162
# Training Epoch 561, Loss = 0.00024786803987808526
# Training Epoch 562, Loss = 0.0002476109948474914
# Training Epoch 563, Loss = 0.00024737039348110557
# Training Epoch 564, Loss = 0.0002471502812113613
# Training Epoch 565, Loss = 0.00024695301544852555
# Training Epoch 566, Loss = 0.00024677152396179736
# Training Epoch 567, Loss = 0.0002465950674377382
# Training Epoch 568, Loss = 0.0002464151766616851
# Training Epoch 569, Loss = 0.0002462306583765894
# Training Epoch 570, Loss = 0.0002460464893374592
# Training Epoch 571, Loss = 0.00024586261133663356
# Training Epoch 572, Loss = 0.000245691800955683
# Training Epoch 573, Loss = 0.0002455306821502745
# Training Epoch 574, Loss = 0.00024537218268960714
# Training Epoch 575, Loss = 0.0002451959881000221
# Training Epoch 576, Loss = 0.0002450023894198239
# Training Epoch 577, Loss = 0.00024478850536979735
# Training Epoch 578, Loss = 0.0002445732243359089
# Training Epoch 579, Loss = 0.0002443654229864478
# Training Epoch 580, Loss = 0.0002441758115310222
# Training Epoch 581, Loss = 0.0002440029929857701
# Training Epoch 582, Loss = 0.0002438379160594195
# Training Epoch 583, Loss = 0.000243672271608375
# Training Epoch 584, Loss = 0.00024349884188268334
# Training Epoch 585, Loss = 0.00024331803433597088
# Training Epoch 586, Loss = 0.00024313354515470564
# Training Epoch 587, Loss = 0.0002429532032692805
# Training Epoch 588, Loss = 0.0002427812578389421
# Training Epoch 589, Loss = 0.00024262038641609251
# Training Epoch 590, Loss = 0.0002424677077215165
# Training Epoch 591, Loss = 0.00024231741554103792
# Training Epoch 592, Loss = 0.0002421623794361949
# Training Epoch 842, Loss = 0.00021243837545625865
# Training Epoch 843, Loss = 0.00021235638996586204
# Training Epoch 844, Loss = 0.00021227548131719232
# Training Epoch 845, Loss = 0.0002121956058545038
# Training Epoch 846, Loss = 0.00021211555576883256
# Training Epoch 847, Loss = 0.0002120354911312461
# Training Epoch 848, Loss = 0.00021195619774516672
# Training Epoch 849, Loss = 0.0002118778502335772
# Training Epoch 850, Loss = 0.00021179928444325924
# Training Epoch 851, Loss = 0.0002117203111993149
# Training Epoch 852, Loss = 0.00021164210920687765
# Training Epoch 853, Loss = 0.00021156479488126934
# Training Epoch 854, Loss = 0.00021148817904759198
# Training Epoch 855, Loss = 0.00021141150500625372
# Training Epoch 856, Loss = 0.00021133467089384794
# Training Epoch 857, Loss = 0.0002112584770657122
# Training Epoch 858, Loss = 0.0002111831126967445
# Training Epoch 859, Loss = 0.00021110786474309862
# Training Epoch 860, Loss = 0.0002110326458932832
# Training Epoch 861, Loss = 0.00021095783449709415
# Training Epoch 862, Loss = 0.00021088385256007314
# Training Epoch 863, Loss = 0.00021081067097838968
# Training Epoch 864, Loss = 0.0002107370091835037
# Training Epoch 865, Loss = 0.00021066336194053292
# Training Epoch 866, Loss = 0.00021059032587800175
# Training Epoch 867, Loss = 0.00021051798830740154
# Training Epoch 868, Loss = 0.00021044648019596934
# Training Epoch 869, Loss = 0.00021037481201346964
# Training Epoch 870, Loss = 0.00021030301286373287
# Training Epoch 871, Loss = 0.00021023208682890981
# Training Epoch 872, Loss = 0.00021016191749367863
# Training Epoch 873, Loss = 0.0002100912679452449
# Training Epoch 874, Loss = 0.00021002066205255687
# Training Epoch 875, Loss = 0.00020995074009988457
# Training Epoch 876, Loss = 0.00020988153119105846
# Training Epoch 877, Loss = 0.0002098127588396892
# Training Epoch 878, Loss = 0.00020974429207853973
# Training Epoch 879, Loss = 0.00020967576710972935
# Training Epoch 880, Loss = 0.00020960785332135856
# Training Epoch 881, Loss = 0.00020954085630364716
# Training Epoch 882, Loss = 0.00020947340817656368
# Training Epoch 883, Loss = 0.00020940600370522588
# Training Epoch 884, Loss = 0.00020933925407007337
# Training Epoch 885, Loss = 0.00020927326113451272
# Training Epoch 886, Loss = 0.0002092078939313069
# Training Epoch 887, Loss = 0.00020914220658596605
# Training Epoch 888, Loss = 0.00020907681027892977
# Training Epoch 889, Loss = 0.00020901209791190922
# Training Epoch 890, Loss = 0.0002089475456159562
# Training Epoch 891, Loss = 0.00020888299332000315
# Training Epoch 892, Loss = 0.0002088189503410831
# Training Epoch 893, Loss = 0.00020875556219834834
# Training Epoch 894, Loss = 0.00020869258150923997
# Training Epoch 895, Loss = 0.0002086296008201316
# Training Epoch 896, Loss = 0.00020856688206549734
# Training Epoch 897, Loss = 0.00020850459986831993
# Training Epoch 898, Loss = 0.00020844301616307348
# Training Epoch 899, Loss = 0.00020838194177486002
# Training Epoch 900, Loss = 0.00020832060545217246
# Training Epoch 901, Loss = 0.00020825945830438286
# Training Epoch 902, Loss = 0.00020819912606384605
# Training Epoch 903, Loss = 0.00020813931769225746
# Training Epoch 261, Loss = 2.6403554329590406e-06
# Training Epoch 262, Loss = 2.6394843644084176e-06
# Training Epoch 263, Loss = 2.6386651370557956e-06
# Training Epoch 264, Loss = 2.637916850289912e-06
# Training Epoch 265, Loss = 2.637276566019864e-06
# Training Epoch 266, Loss = 2.6367899863544153e-06
# Training Epoch 267, Loss = 2.636466660987935e-06
# Training Epoch 268, Loss = 2.636380486364942e-06
# Training Epoch 269, Loss = 2.6365119083493482e-06
# Training Epoch 270, Loss = 2.6370476007286925e-06
# Training Epoch 271, Loss = 2.6380057533970103e-06
# Training Epoch 272, Loss = 2.639655804159702e-06
# Training Epoch 273, Loss = 2.6419518235343276e-06
# Training Epoch 274, Loss = 2.6451566554897e-06
# Training Epoch 275, Loss = 2.6491736662137555e-06
# Training Epoch 276, Loss = 2.6541804345470155e-06
# Training Epoch 277, Loss = 2.6595801045914413e-06
# Training Epoch 278, Loss = 2.6648517632565927e-06
# Training Epoch 279, Loss = 2.66861070485902e-06
# Training Epoch 280, Loss = 2.6698414785641944e-06
# Training Epoch 281, Loss = 2.6671682462620083e-06
# Training Epoch 282, Loss = 2.6605798666423652e-06
# Training Epoch 283, Loss = 2.6506038466322934e-06
# Training Epoch 284, Loss = 2.6394998258183477e-06
# Training Epoch 285, Loss = 2.6293066639482277e-06
# Training Epoch 286, Loss = 2.6221098323730985e-06
# Training Epoch 287, Loss = 2.618595544845448e-06
# Training Epoch 288, Loss = 2.618481630634051e-06
# Training Epoch 289, Loss = 2.620649638629402e-06
# Training Epoch 290, Loss = 2.6236784833599813e-06
# Training Epoch 291, Loss = 2.6263021482009208e-06
# Training Epoch 292, Loss = 2.6274358333466807e-06
# Training Epoch 293, Loss = 2.6268514830007916e-06
# Training Epoch 294, Loss = 2.624340595502872e-06
# Training Epoch 295, Loss = 2.620745135573088e-06
# Training Epoch 296, Loss = 2.6166142106376356e-06
# Training Epoch 297, Loss = 2.6129616799153155e-06
# Training Epoch 298, Loss = 2.6102850370079977e-06
# Training Epoch 299, Loss = 2.6087941478181165e-06
# Runtime:2:00:37.071987

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,4))
axs[0].plot(fwi_loss)
axs[0].set_title('Data Loss')
axs[0].set_xlabel('Iteration')
axs[0].spines['right'].set_visible(False)
axs[0].spines['top'].set_visible(False)
axs[1].plot(ssim_list)
axs[1].set_title('SSIM')
axs[1].set_xlabel('Iteration')
axs[1].spines['right'].set_visible(False)
axs[1].spines['top'].set_visible(False)
plt.savefig(f'{exp_name}/losses.png',  bbox_inches='tight', dpi=300)

# %%
show_one_iter_dm(grad.cpu(), dm1.cpu(), g.cpu(), dm.cpu(), model.detach().cpu(), lossn, iteration=FWI_iter,
                cmap='bwr', vmin=m_vmin, vmax=m_vmax, extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),)

# %%
show_model(updates[0], cmap='jet', vmin=m_vmin, vmax=m_vmax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='First update')

# %%
show_model(updates[-1], cmap='jet', vmin=m_vmin, vmax=m_vmax, figsize=(12, 5), extent=(0, par['nx']*par['dx']*1000, par['nz']*par['dx']*1000, 0),
           title='Last update')
