# %% [markdown]
# ## Install project dependencies

# %%
#pip install deepwave==0.0.22
# Out:
# ...
#   Using cached deepwave-0.0.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.3 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# ...
#   Using cached nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# ...
#   Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ...
#   Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# ...

# %% [markdown]
# ## Add your develoments

# %%
# Library Imports
import numpy as np  # Numerical operations on arrays
import matplotlib.pyplot as plt  # Plotting library
import os

# Deepwave Imports
# import deepwave
# from deepwave import scalar  # Scalar wave propagation

# %%
# ============================================================
# Data access
# Option 1: mount Google Drive to access existing files
# Option 2: load file stored in the cloned GitHub repo
#           Use this when the data files are small and part of
#           the project repository
# ============================================================

# ---------- Option 1: Google Drive ----------
from google.colab import drive
drive.mount('/content/drive')
# !ls
# Set your data directory here.
DATA_DIR = '/content/drive/MyDrive/Colab Notebooks/data'
os.chdir(DATA_DIR)
# !ls

# ---------- Option 2: files inside the cloned repository ----------
# Example:
# DATA_DIR = '/content/piml-pub/proj-01/data'

# %%
dirmodel = '/mnt/storage_C1/eliani_beloni/geofisica/piml-pub/pinn/'
modelhdr =  open(dirmodel+'gaussian_anomaly.hdr','r')
# Read the first line of header file
[nz,ny,oz,oy,dz,dy] = modelhdr.readline().strip().split()
nz, ny = int(nz), int(ny)  # Convert n1 and n2 to integers
oz,oy,dz,dy = float(oz), float(oy), float(dz), float(dy)
# Read the second line of header file
velbin = modelhdr.readline().strip()
print(velbin)
f =  open(dirmodel+velbin,'rb')
print(f)
modelnpy = np.fromfile(f,dtype='f4',count=nz*ny)
modelnpy = modelnpy.reshape([nz, ny],order='F')
f.close()

# Construct z and y axes arrays
z_values = np.arange(oz, oz + nz * dz, dz)
y_values = np.arange(oy, oy + ny * dy, dy)

# Obtain max and min values
maxval = np.max(modelnpy)
minval = np.min(modelnpy)

# Plot the image
plt.imshow(modelnpy, cmap='jet', extent=[y_values[0], y_values[-1], z_values[-1], z_values[0]])
# Adjust color scale limitsi
plt.clim(vmin=minval, vmax=maxval)
# Add colorbar
cbar = plt.colorbar(shrink=0.5)
cbar.ax.tick_params(labelsize=10)
tick_values = np.arange(minval, maxval + 1, 250)
cbar.set_ticks(tick_values)

# Add title and labels
plt.title('Gaussian anomaly model')
plt.xlabel('Distance (m)')
plt.ylabel('Depth (m)')
# Set colorbar label on top
cbar.set_label(r'$V_p$ (m/s)', labelpad=-18, y=1.16, rotation=0)

plt.show()
# Out:
# gaussian_anomaly.bin
# <_io.BufferedReader name='/mnt/storage_C1/eliani_beloni/geofisica/piml-pub/pinn/gaussian_anomaly.bin'>
