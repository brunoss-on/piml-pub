# %%
# Configure Git (needed once per Colab session)
# !git config --global user.name "Your Name"
# !git config --global user.email "your.email@example.com"
# Clone your own branch
# !git clone https://github.com/brunoss-on/piml-pub.git
# Enter the repository directory
# %cd piml-pub/proj-02
# List files
# !ls

# %%
# Install project dependencies
# !pip install deepwave==0.0.22

# %%
# Add your develoments

# %%
# Save your work (commit and push)

# Ensure you are inside the repository
# %cd /content/piml-pub

# Check changes
# !git status
# Add changes
# !git add .
# Commit
# !git commit -m "Update notebook"
# Push to your branch
# !git push origin your-branch-name
