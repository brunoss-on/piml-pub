# %%
# ==========================================
# CELL-1: HARDWARE & GLOBAL ENVIRONMENT SETUP
# ==========================================
import os
import torch
import deepwave
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="deepwave")

# 1. Global Directory Paths (Assumes notebook is in /notebooks)
PROJECT_ROOT = os.path.abspath(os.path.join(".."))
DATA_DIR = os.path.join(PROJECT_ROOT, "data")
FIGURES_DIR = os.path.join(PROJECT_ROOT, "figures")

# Ensure the output directory exists
os.makedirs(FIGURES_DIR, exist_ok=True)

# 2. Strict Device Allocation
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"HPC Node Active: {device}")
print(f"Figures Directory Set: {FIGURES_DIR}")

# %%
# ==========================================
# EXPORTING A VISUALIZATION (Anywhere in the notebook)
# ==========================================

# ... (your plotting code: fig, ax = plt.subplots...) ...

# 1. Define the specific filename for this plot
output_file = os.path.join(FIGURES_DIR, "ddr_pinn_phase1_multishot.png")

# 2. Save it
fig.savefig(output_file, dpi=300, bbox_inches='tight')
plt.show()

print(f"Dashboard successfully exported to: {output_file}")
